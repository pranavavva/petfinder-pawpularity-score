# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set()

# %%
train_meta = pd.read_csv("train.csv")

# %%
train_meta.head()
# Out:
#                                  Id  Subject Focus  Eyes  Face  Near  Action  \
# 0  0007de18844b0dbbb5e1f607da0606e0              0     1     1     1       0
# 1  0009c66b9439883ba2750fb825e1d7db              0     1     1     0       0
# 2  0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1       0
# 3  0018df346ac9c1d8413cfcc888ca8246              0     1     1     1       0
# 4  001dc955e10590d3ca4673f034feeef2              0     0     0     1       0
#
#    Accessory  Group  Collage  Human  Occlusion  Info  Blur  Pawpularity
# 0          0      1        0      0          0     0     0           63
# 1          0      0        0      0          0     0     0           42
# 2          0      0        0      1          1     0     0           28
# 3          0      0        0      0          0     0     0           15
# 4          0      1        0      0          0     0     0           72

# %%
pawularity_corr = train_meta \
    .drop("Id", axis=1) \
    .corr()[["Pawpularity"]] \
    .sort_values("Pawpularity", ascending=False) \
    .drop("Pawpularity")

plt.figure(figsize=(12, 8))
sns.heatmap(pawularity_corr, annot=True, cmap="magma")
# Out:
# <AxesSubplot:>

# %%
from IPython.display import display, Image

most_popular = ["./train/" + train_meta[["Id", "Pawpularity"]].sort_values("Pawpularity", ascending=False)["Id"][i] + ".jpg" for i in range(3)]

for image in most_popular:
    display(Image(image))
